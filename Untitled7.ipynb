# %% [markdown]
# <a href="https://colab.research.google.com/github/GabrielFernandesDEV/AWS-Machine-Learning-Foundations/blob/main/Untitled7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Pós-graduação em Ciência de Dados e Machine Learning
#
# #### Disciplina: **Introdução a Aprendizagem De Máquina**
#
# #### Projeto Final para disciplina Introdução a Aprendizagem De Máquina
#
# <BR>
#
#
# #### Nome:
# #### RA:

# %% [markdown]
# ## Descrição do Problema
#
# Descreva o problema que deseja resolver com machine learning fazendo um breve resumo do dataset. Utilizem algum dataset que não foi tratado no decorrer do curso. Seria interessante que a base de dados seja referente a algum caso real.
#
# Em seguida, expliquem o porque escolheram o algoritmo de machine learning que vão usar para solucionar o problema.
#
# Seguem alguns sites para download de datasets:
#
# http://archive.ics.uci.edu/ml/index.php
#
# https://www.kaggle.com/
#
# https://dados.gov.br/dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from sklearn.svm import SVC
from sklearn import metrics
from sklearn.model_selection import train_test_split,ShuffleSplit
import warnings
warnings.filterwarnings('ignore')

sns.set_style('whitegrid')
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from itertools import chain
from plotly import tools
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
import plotly.offline as py
from plotly.graph_objs import Scatter, Layout
py.init_notebook_mode(connected=True)
import plotly.graph_objs as go
import plotly.figure_factory as ff
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
# Python libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import itertools
from itertools import chain
from sklearn.feature_selection import RFE
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import VotingClassifier
from sklearn.model_selection import GridSearchCV, cross_val_score, learning_curve, train_test_split
from sklearn.metrics import precision_score, recall_score, confusion_matrix, roc_curve, precision_recall_curve, accuracy_score
import warnings
import plotly.offline as py
py.init_notebook_mode(connected=True)
import plotly.graph_objs as go
import plotly.tools as tls
import plotly.figure_factory as ff

warnings.filterwarnings('ignore') #ignore warning messages
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# ## Dataset
#
# Leia o dataset
#
# Caso seja de um arquivo envie o dataset junto com este notebook.

# %%
data=pd.read_csv("data.csv")

# %%
data.head(10)
# Out:
#          id diagnosis  ...  symmetry_worst  fractal_dimension_worst
# 0    842302         M  ...          0.4601                  0.11890
# 1    842517         M  ...          0.2750                  0.08902
# 2  84300903         M  ...          0.3613                  0.08758
# 3  84348301         M  ...          0.6638                  0.17300
# 4  84358402         M  ...          0.2364                  0.07678
# 5    843786         M  ...          0.3985                  0.12440
# 6    844359         M  ...          0.3063                  0.08368
# 7  84458202         M  ...          0.3196                  0.11510
# 8    844981         M  ...          0.4378                  0.10720
# 9  84501001         M  ...          0.4366                  0.20750
#
# [10 rows x 32 columns]

# %% [markdown]
# # Tratamento dos dados
# Pré processamento dos dados

# %%
from sklearn.preprocessing import LabelEncoder

labelencoder = LabelEncoder()
data.iloc[:,1] = labelencoder.fit_transform(data.iloc[:,1].values)

data.iloc[:,1]
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 564    1
# 565    1
# 566    1
# 567    1
# 568    0
# Name: diagnosis, Length: 569, dtype: int64

# %%
state_region={1:'M',0:'B'}
data['diag']=data['diagnosis'].map(state_region)

# %% [markdown]
# # Vizualização dos dados
# Gráficos

# %%
ax = sns.countplot(data['diag'],label="Count")       # M = 212, B = 357
B, M = data['diag'].value_counts()
print('Number of Benign: ',B)
print('Number of Malignant : ',M)
# Out:
# Number of Benign:  357
# Number of Malignant :  212

# %%
mean_col = [col for col in data.columns if col.endswith('_mean')]
for i in range(len(mean_col)):
    sns.FacetGrid(data,hue="diag",aspect=3,margin_titles=True).map(sns.kdeplot,mean_col[i],shade= True).add_legend()

# %% [markdown]
# #Podemos dizer que duas variáveis ​​estão relacionadas entre si, se uma delas fornecer informações sobre as outras
#
# #Portanto, podemos dizer que a distância estão positivamente relacionados um com o outro.
#
# #Gráfico de dispersão: maneira mais simples de verificar a relação entre duas variáveis
#
# #Vejamos a relação entre a média do raio e a média da área. No gráfico de dispersão, você pode ver que quando a média do raio aumenta, a média da área também aumenta. Portanto, eles estão positivamente correlacionados entre si.
#
# #Não há correlação entre a média da área e a dimensão fractal se. Porque quando a média da área muda, a dimensão fractal se não é afetada pela chance da média da área

# %%
plt.figure(figsize=(14,10))
sns.heatmap(data.iloc[:,1:12].corr(), annot=True)
plt.title('Correlation Map')
# Out:
# Text(0.5, 1.0, 'Correlation Map')

# %% [markdown]
# # Matriz enorme que inclui muitos números
#
#
#
# #O intervalo destes números é de -1 a 1.
#
#
#
# #O significado de 1 é que duas variáveis estão positivamente correlacionadas uma com a outra como a média do raio e a média da área O significado de zero é que não há correlação entre as variáveis
#
#
#
# #O significado de -1 é que duas variáveis estão negativamente correlacionadas entre si. Na verdade, a correlação entre elas não é -1, é -0,3, mas a ideia é que se o sinal de correlação for negativo isso significa que há correlação negativa.

# %%
# Def X and Y
y = np.array(data.diagnosis.tolist())
data = data.drop('diagnosis', 1)
X = np.array(data.values)

# %%
# Normalization
scaler = StandardScaler()
X = scaler.fit_transform(X)

# %%
# Train_test split
random_state = 42
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.12, random_state = random_state)

# %%
# Find best hyperparameters (accuracy)
log_clf = LogisticRegression(random_state = random_state)
param_grid = {
            'penalty' : ['l2','l1'],  
            'C' : [0.001, 0.01, 0.1, 1, 10, 100, 1000]
            }

CV_log_clf = GridSearchCV(estimator = log_clf, param_grid = param_grid , scoring = 'accuracy', verbose = 1, n_jobs = -1)
CV_log_clf.fit(X_train, y_train)

best_parameters = CV_log_clf.best_params_
print('The best parameters for using this model is', best_parameters)
# Out:
# Fitting 5 folds for each of 14 candidates, totalling 70 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# The best parameters for using this model is {'C': 0.1, 'penalty': 'l2'}
# [Parallel(n_jobs=-1)]: Done  70 out of  70 | elapsed:    1.5s finished

# %%
def plot_confusion_matrix(cm, classes,
                          normalize = False,
                          title = 'Confusion matrix"',
                          cmap = plt.cm.Blues) :
    plt.imshow(cm, interpolation = 'nearest', cmap = cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation = 0)
    plt.yticks(tick_marks, classes)

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])) :
        plt.text(j, i, cm[i, j],
                 horizontalalignment = 'center',
                 color = 'white' if cm[i, j] > thresh else 'black')

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    
# Show metrics 
def show_metrics():
    tp = cm[1,1]
    fn = cm[1,0]
    fp = cm[0,1]
    tn = cm[0,0]
    print('Accuracy  =     {:.3f}'.format((tp+tn)/(tp+tn+fp+fn)))
    print('Precision =     {:.3f}'.format(tp/(tp+fp)))
    print('Recall    =     {:.3f}'.format(tp/(tp+fn)))
    print('F1_score  =     {:.3f}'.format(2*(((tp/(tp+fp))*(tp/(tp+fn)))/
                                                 ((tp/(tp+fp))+(tp/(tp+fn))))))

# %%
# ROC curve
def plot_roc():
    plt.plot(fpr, tpr, label = 'ROC curve', linewidth = 2)
    plt.plot([0,1],[0,1], 'k--', linewidth = 2)
   # plt.xlim([0.0,0.001])
   # plt.ylim([0.0,1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('ROC Curve')
    plt.show();

# %%
#Log with best hyperparameters
CV_log_clf = LogisticRegression(C = best_parameters['C'], 
                                penalty = best_parameters['penalty'], 
                                random_state = random_state)

CV_log_clf.fit(X_train, y_train)
y_pred = CV_log_clf.predict(X_test)
y_score = CV_log_clf.decision_function(X_test)

# Confusion maxtrix & metrics
cm = confusion_matrix(y_test, y_pred)
class_names = [0,1]
plt.figure()
plot_confusion_matrix(cm, 
                      classes=class_names, 
                      title='Logistic Confusion matrix')
plt.savefig('6')
plt.show()

show_metrics()

# ROC curve
fpr, tpr, t = roc_curve(y_test, y_score)
plot_roc()
# Out:
# Accuracy  =     0.986
# Precision =     1.000
# Recall    =     0.957
# F1_score  =     0.978

# %%
# Learning curve
def plot_learning_curve(estimator, title, X, y, ylim = None, cv = None,
                        n_jobs = 1, train_sizes = np.linspace(.1, 1.0, 5)):
    """
    Plots a learning curve. http://scikit-learn.org/stable/modules/learning_curve.html
    """
    plt.figure()
    plt.title(title)
    if ylim is not None:
        plt.ylim(*ylim)
    plt.xlabel('Training examples')
    plt.ylabel('Score')
    train_sizes, train_scores, test_scores = learning_curve(
        estimator, X, y, cv = cv, n_jobs = n_jobs, train_sizes = train_sizes)
    train_scores_mean = np.mean(train_scores, axis = 1)
    train_scores_std = np.std(train_scores, axis = 1)
    test_scores_mean = np.mean(test_scores, axis = 1)
    test_scores_std = np.std(test_scores, axis = 1)
    plt.grid()
    plt.fill_between(train_sizes, train_scores_mean - train_scores_std,
                     train_scores_mean + train_scores_std, alpha=0.1,
                     color="r")
    plt.fill_between(train_sizes, test_scores_mean - test_scores_std,
                     test_scores_mean + test_scores_std, alpha = 0.1, color = "g")
    plt.plot(train_sizes, train_scores_mean, 'o-', color = "r",
             label = "Training score")
    plt.plot(train_sizes, test_scores_mean, 'o-', color = "g",
             label = "Cross-validation score")
    plt.legend(loc = "best")
    return plt

# %%
selector = RFE(log_clf)
selector = selector.fit(X_train, y_train)

# %%
plot_learning_curve(selector, 'Learning Curve For Logistic Model with RFE', X, y, (0.85,1.05), 10)
plt.show()

# %%
plot_learning_curve(CV_log_clf, 'Learning Curve For Logistic Model', X, y, (0.85,1.05), 10)
plt.savefig('7')
plt.show()
